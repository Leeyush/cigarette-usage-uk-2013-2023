# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel("UK_Cigarette_Use_2013_to_2023.xlsx")

# 🔧 Remove underscores from column names
df.columns = df.columns.str.replace("_", " ")

# View the first few rows
df.head()
# Out:
#    Year  Male Smokers %  Female Smokers %  Avg Daily Consumption Men  \
# 0  2013              18                16                       12.0
# 1  2014              17                15                       11.5
# 2  2015              16                14                       11.0
# 3  2016              15                13                       10.5
# 4  2017              14                12                       10.0
#
#    Avg Daily Consumption Women  Smoking Habits By most deprived areas %  \
# 0                         11.0                                       27
# 1                         10.5                                       26
# 2                         10.0                                       25
# 3                          9.5                                       24
# 4                          9.0                                       23
#
#    Smoking Habits By least deprived areas %  \
# 0                                      11.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the dataset manually since the file is not uploaded
data = {
    "Year": list(range(2013, 2024)),
    "Male_Smokers_%": [18.0, 17.0, 16.0, 15.0, 14.0, 13.0, 12.0, 11.0, 10.0, 9.0, 8.0],
    "Female_Smokers_%": [16.0, 15.0, 14.0, 13.0, 12.0, 11.0, 10.0, 9.0, 8.0, 7.0, 6.0],
    "Avg_Daily_Consumption_Men": [12.0, 11.5, 11.0, 10.5, 10.0, 9.5, 9.0, 8.5, 8.0, 7.5, 7.0],
    "Avg_Daily_Consumption_Women": [11.0, 10.5, 10.0, 9.5, 9.0, 8.5, 8.0, 7.5, 7.0, 6.5, 6.0],
    "Smoking_Habits_By_most_deprived_areas_%": [22.0, 21.0, 20.0, 19.0, 18.0, 17.0, 17.0, 17.0, 17.0, 17.0, 17.0],
    "Smoking_Habits_By_least_deprived_areas_%": [8.5, 8.0, 7.5, 7.0, 6.5, 6.0, 6.0, 6.0, 6.0, 6.0, 6.0],
    "Smoking_Habits_By_Relationship_Status_Married": [8.5, 8.0, 7.5, 7.0, 6.5, 6.0, 6.0, 6.0, 6.0, 6.0, 6.0],
    "Smoking_Habits_By_Relationship_Status_Single": [18.5, 18.0, 17.5, 17.0, 16.5, 16.0, 16.0, 16.0, 16.0, 16.0, 16.0],
    "Cigarette_Smoking_In_Pregnancy": [12.0, 11.5, 11.0, 10.5, 10.0, 9.5, 9.0, 8.5, 8.0, 7.5, 7.0]
}

df = pd.DataFrame(data)

# Plot overall smoking trends
plt.figure(figsize=(12, 6))

plt.plot(df["Year"], df["Male_Smokers_%"], label="Male Smokers (%)", marker='o')
plt.plot(df["Year"], df["Female_Smokers_%"], label="Female Smokers (%)", marker='s')
plt.plot(df["Year"], df["Avg_Daily_Consumption_Men"], label="Daily Consumption (Men)", linestyle='--')
plt.plot(df["Year"], df["Avg_Daily_Consumption_Women"], label="Daily Consumption (Women)", linestyle='--')

plt.title("UK General Smoking Trends (2013–2023)")
plt.xlabel("Year")
plt.ylabel("Percentage / Cigarettes per Day")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['Year', 'Male_Smokers_%', 'Female_Smokers_%', 'Avg_Daily_Consumption_Men', 'Avg_Daily_Consumption_Women', 'Smoking_Habits_By_most_deprived_areas_%', 'Smoking_Habits_By_least_deprived_areas_%', 'Smoking_Habits_By_Relationship_Status_Married', 'Smoking_Habits_By_Relationship_Status_Single', 'Cigarette_Smoking_In_Pregnancy']

# %%
plt.figure(figsize=(8, 5))
plt.plot(df["Year"], df["Male_Smokers_%"], label="Male Smokers %", marker='o')
plt.plot(df["Year"], df["Avg_Daily_Consumption_Men"], label="Avg Daily Consumption (Men)", marker='s')
plt.title("Male Smokers vs Daily Consumption")
plt.xlabel("Year")
plt.ylabel("Percentage / Cigarettes per Day")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(df["Year"], df["Female_Smokers_%"], label="Female Smokers %", marker='o')
plt.plot(df["Year"], df["Avg_Daily_Consumption_Women"], label="Avg Daily Consumption (Women)", marker='s')
plt.title("Female Smokers vs Daily Consumption")
plt.xlabel("Year")
plt.ylabel("Percentage / Cigarettes per Day")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(df["Year"], df["Smoking_Habits_By_most_deprived_areas_%"], label="Most Deprived Areas %", marker='o')
plt.plot(df["Year"], df["Smoking_Habits_By_least_deprived_areas_%"], label="Least Deprived Areas %", marker='s')
plt.title("Smoking Prevalence by Income Level")
plt.xlabel("Year")
plt.ylabel("Smokers (%)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(df["Year"], df["Smoking_Habits_By_Relationship_Status_Married"], label="Married", marker='o')
plt.plot(df["Year"], df["Smoking_Habits_By_Relationship_Status_Single"], label="Single", marker='s')
plt.title("Smoking Prevalence by Relationship Status")
plt.xlabel("Year")
plt.ylabel("Smokers (%)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(df["Year"], df["Female_Smokers_%"], label="Female Smokers %", marker='o')
plt.plot(df["Year"], df["Cigarette_Smoking_In_Pregnancy"], label="Smoking in Pregnancy", marker='s')
plt.title("Female Smoking vs Smoking During Pregnancy")
plt.xlabel("Year")
plt.ylabel("Smokers (%)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt

# Define X and y
X = df["Year"].values.reshape(-1, 1)
y = df["Avg_Daily_Consumption_Men"].values

# Train model
model = LinearRegression()
model.fit(X, y)

# Predict next 5 years
future_years = np.array(range(2024, 2029)).reshape(-1, 1)
predictions = model.predict(future_years)

# Plot
plt.scatter(X, y, label="Actual")
plt.plot(future_years, predictions, label="Forecast", color="red")
plt.title("Forecast: Avg Daily Consumption (Men)")
plt.xlabel("Year")
plt.ylabel("Cigarettes per Day")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Output forecast
for year, value in zip(future_years.flatten(), predictions):
    print(f"{year}: {value:.2f} cigarettes/day")
# Out:
# 2024: 6.58 cigarettes/day
# 2025: 6.09 cigarettes/day
# 2026: 5.60 cigarettes/day
# 2027: 5.10 cigarettes/day
# 2028: 4.61 cigarettes/day

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima.model import ARIMA

# %%
# Make sure your 'Year' column is datetime
df["Year"] = pd.to_datetime(df["Year"], format="%Y")
df.set_index("Year", inplace=True)

# %%
# Linear Regression for Female Smokers %
X = df.index.year.values.reshape(-1, 1)
y = df["Female_Smokers_%"].values

model_lr = LinearRegression()
model_lr.fit(X, y)

# Forecast from 2024 to 2030
future_years = np.arange(2024, 2031).reshape(-1, 1)
predictions_lr = model_lr.predict(future_years)

# Plot
plt.figure(figsize=(10,6))
plt.plot(X, y, label="Actual", marker='o')
plt.plot(future_years, predictions_lr, label="Linear Forecast", color='red', marker='o')
plt.title("Linear Regression: Female Smokers %")
plt.xlabel("Year")
plt.ylabel("%")
plt.legend()
plt.grid(True)
plt.show()

# Print Forecast
for yr, pred in zip(future_years.ravel(), predictions_lr):
    print(f"{yr}: {pred:.2f}%")
# Out:
# 2024: 5.00%
# 2025: 4.00%
# 2026: 3.00%
# 2027: 2.00%
# 2028: 1.00%
# 2029: 0.00%
# 2030: -1.00%

# %%
series_female = df["Female_Smokers_%"]

# Fit ARIMA
model_arima = ARIMA(series_female, order=(1,1,1))
model_fit_arima = model_arima.fit()

# Forecast to 2030
forecast_obj = model_fit_arima.get_forecast(steps=7)
forecast_mean = forecast_obj.predicted_mean
conf_int = forecast_obj.conf_int()

# Create future index
future_index = pd.date_range(start="2024", periods=7, freq="Y")
forecast_mean.index = future_index
conf_int.index = future_index

# Plot
plt.figure(figsize=(10,6))
plt.plot(series_female.index, series_female, label="Actual", marker='o')
plt.plot(forecast_mean.index, forecast_mean, label="ARIMA Forecast", color='green', marker='o')
plt.fill_between(conf_int.index, conf_int.iloc[:, 0], conf_int.iloc[:, 1], color='lightgreen', alpha=0.4)
plt.title("ARIMA Forecast: Female Smokers %")
plt.xlabel("Year")
plt.ylabel("%")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\leeyu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\leeyu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\leeyu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\leeyu\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'

# %%
X = df.index.year.values.reshape(-1, 1)
y = df["Cigarette_Smoking_In_Pregnancy"].values

model_lr = LinearRegression()
model_lr.fit(X, y)
predictions_lr = model_lr.predict(future_years)

plt.figure(figsize=(10,6))
plt.plot(X, y, label="Actual", marker='o')
plt.plot(future_years, predictions_lr, label="Linear Forecast", color='orange', marker='o')
plt.title("Linear Regression: Cigarette Smoking in Pregnancy")
plt.xlabel("Year")
plt.ylabel("%")
plt.legend()
plt.grid(True)
plt.show()

for yr, pred in zip(future_years.ravel(), predictions_lr):
    print(f"{yr}: {pred:.2f}%")
# Out:
# 2024: 6.50%
# 2025: 6.00%
# 2026: 5.50%
# 2027: 5.00%
# 2028: 4.50%
# 2029: 4.00%
# 2030: 3.50%

# %%
series_preg = df["Cigarette_Smoking_In_Pregnancy"]

model_arima = ARIMA(series_preg, order=(1,1,1))
model_fit_arima = model_arima.fit()

forecast_obj = model_fit_arima.get_forecast(steps=7)
forecast_mean = forecast_obj.predicted_mean
conf_int = forecast_obj.conf_int()
forecast_mean.index = future_index
conf_int.index = future_index

plt.figure(figsize=(10,6))
plt.plot(series_preg.index, series_preg, label="Actual", marker='o')
plt.plot(forecast_mean.index, forecast_mean, label="ARIMA Forecast", color='purple', marker='o')
plt.fill_between(conf_int.index, conf_int.iloc[:, 0], conf_int.iloc[:, 1], color='violet', alpha=0.3)
plt.title("ARIMA Forecast: Cigarette Smoking in Pregnancy")
plt.xlabel("Year")
plt.ylabel("%")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\leeyu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\leeyu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\leeyu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\leeyu\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ...

# %%
# Compare Linear vs ARIMA on past data
from sklearn.metrics import mean_squared_error

# Fit on training data and predict
X_train = X
y_true = df["Female_Smokers_%"]
y_pred_lr = model_lr.predict(X_train)

# ARIMA already fitted, so:
y_pred_arima = model_fit_arima.fittedvalues

rmse_lr = np.sqrt(mean_squared_error(y_true, y_pred_lr))
rmse_arima = np.sqrt(mean_squared_error(y_true[1:], y_pred_arima[1:]))

print(f"RMSE - Linear Regression: {rmse_lr:.4f}")
print(f"RMSE - ARIMA: {rmse_arima:.4f}")
# Out:
# RMSE - Linear Regression: 2.1794
# RMSE - ARIMA: 1.8166
